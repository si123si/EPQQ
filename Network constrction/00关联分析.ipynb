# %% [markdown]
# ###关联分析，筛选强关联规则

# %%
import os
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder


# 设定文件路径
#directory = "D:/研究生论文/小论文2/代码/02质量特征识别/02质量特征匹配结果/无限世界4.8_每集/"

directory = "D:/研究生论文/小论文2/代码/02RAG_质量特征匹配阶段/RAG代码/01输出数据/桃花马上请长缨_每集/"

# 循环遍历文件
for episode in range(1, 92):
    # 构造文件路径
    file_path = os.path.join(directory, f"mapped_info_episode_{episode}.xlsx")
    
    # 读取数据
    data = pd.read_excel(file_path)
    
    # 合并三列为一列，并使用 '|' 连接
    merged_features = data[['Feature_1', 'Feature_2', 'Feature_3']].astype(str).apply(lambda x: '|'.join(x), axis=1)
    
    # 将合并后的列添加到原始数据框中
    data['Merged_Features'] = merged_features
    
    # 对合并后的数据进行处理，转换成适合关联分析的格式
    transaction_list = data['Merged_Features'].apply(lambda x: x.split('|')).tolist()
    
    # 使用 TransactionEncoder 进行编码
    te = TransactionEncoder()
    te_ary = te.fit(transaction_list).transform(transaction_list)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    
    # 使用 Apriori 算法找出频繁项集
    frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)
    
    # 根据频繁项集生成关联规则
    rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
    
    # 排序
    rules = rules.sort_values(by=['support', 'confidence', 'lift'], ascending=[False, False, False])
    
    # 提取关联规则中的项并合并到一列
    rules['merged_items'] = rules.apply(lambda row: '|'.join(row['antecedents']) + '|' + '|'.join(row['consequents']), axis=1)
    
    # 保存结果
    output_file_path = f"D:/研究生论文/小论文2/代码/03网络图/00关联分析_强关联规则/输出结果/01关联规则结果/桃花马上请长缨RAG/第{episode}集.xlsx"
    rules.to_excel(output_file_path, index=False)
    
    # 打印关联规则
    print(f"第{episode}集关联规则：")
    print(rules)
# Out:
# C:\Users\lenovo\AppData\Roaming\Python\Python311\site-packages\mlxtend\frequent_patterns\association_rules.py:186: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)
# C:\Users\lenovo\AppData\Roaming\Python\Python311\site-packages\mlxtend\frequent_patterns\association_rules.py:186: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)
# 第73集关联规则：
#         antecedents      consequents  antecedent support  consequent support  \
# 6           (剧情合理性)           (角色表现)            0.857143            1.000000
# 7            (角色表现)          (剧情合理性)            1.000000            0.857143
# 11           (台词质量)           (角色表现)            0.571429            1.000000
# 10           (角色表现)           (台词质量)            1.000000            0.571429
# 28    (剧情合理性, 台词质量)           (角色表现)            0.428571            1.000000
# 29           (角色表现)    (剧情合理性, 台词质量)            1.000000            0.428571
# 1             (nan)          (剧情合理性)            0.285714            0.857143
# 18      (nan, 角色表现)          (剧情合理性)            0.285714            0.857143
# 21            (nan)    (剧情合理性, 角色表现)            0.285714            0.857143
# 3             (nan)           (角色表现)            0.285714            1.000000
# 17     (剧情合理性, nan)           (角色表现)            0.285714            1.000000
# 0           (剧情合理性)            (nan)            0.857143            0.285714
# 16    (剧情合理性, 角色表现)            (nan)            0.857143            0.285714
# 19          (剧情合理性)      (nan, 角色表现)            0.857143            0.285714
# 2            (角色表现)            (nan)            1.000000            0.285714
# 20           (角色表现)     (剧情合理性, nan)            1.000000            0.285714
# 12          (音效与配乐)           (台词质量)            0.142857            0.571429
# 30    (音效与配乐, 角色表现)           (台词质量)            0.142857            0.571429
# 33          (音效与配乐)     (角色表现, 台词质量)            0.142857            0.571429
# 5          (动作场面呈现)          (剧情合理性)            0.142857            0.857143
# 24   (动作场面呈现, 角色表现)          (剧情合理性)            0.142857            0.857143
# 26         (动作场面呈现)    (剧情合理性, 角色表现)            0.142857            0.857143
# 8          (动作场面呈现)           (角色表现)            0.142857            1.000000
# 14          (音效与配乐)           (角色表现)            0.142857            1.000000
# 22  (剧情合理性, 动作场面呈现)           (角色表现)            0.142857            1.000000
# 31    (音效与配乐, 台词质量)           (角色表现)            0.142857            1.000000
# 13           (台词质量)          (音效与配乐)            0.571429            0.142857
# 32     (角色表现, 台词质量)          (音效与配乐)            0.571429            0.142857
# 35           (台词质量)    (音效与配乐, 角色表现)            0.571429            0.142857
# 4           (剧情合理性)         (动作场面呈现)            0.857143            0.142857
# 23    (剧情合理性, 角色表现)         (动作场面呈现)            0.857143            0.142857
# 25          (剧情合理性)   (动作场面呈现, 角色表现)            0.857143            0.142857
# 9            (角色表现)         (动作场面呈现)            1.000000            0.142857
# 15           (角色表现)          (音效与配乐)            1.000000            0.142857
# 27           (角色表现)  (剧情合理性, 动作场面呈现)            1.000000            0.142857
# 34           (角色表现)    (音效与配乐, 台词质量)            1.000000            0.142857
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 6   0.857143    1.000000  1.000000               1.0  0.000000         inf
# 7   0.857143    0.857143  1.000000               1.0  0.000000    1.000000
# 11  0.571429    1.000000  1.000000               1.0  0.000000         inf
# 10  0.571429    0.571429  1.000000               1.0  0.000000    1.000000
# 28  0.428571    1.000000  1.000000               1.0  0.000000         inf
# 29  0.428571    0.428571  1.000000               1.0  0.000000    1.000000
# 1   0.285714    1.000000  1.166667               1.0  0.040816         inf
# 18  0.285714    1.000000  1.166667               1.0  0.040816         inf
# 21  0.285714    1.000000  1.166667               1.0  0.040816         inf
# 3   0.285714    1.000000  1.000000               1.0  0.000000         inf
# 17  0.285714    1.000000  1.000000               1.0  0.000000         inf
# 0   0.285714    0.333333  1.166667               1.0  0.040816    1.071429
# 16  0.285714    0.333333  1.166667               1.0  0.040816    1.071429
# 19  0.285714    0.333333  1.166667               1.0  0.040816    1.071429
# 2   0.285714    0.285714  1.000000               1.0  0.000000    1.000000
# 20  0.285714    0.285714  1.000000               1.0  0.000000    1.000000
# 12  0.142857    1.000000  1.750000               1.0  0.061224         inf
# 30  0.142857    1.000000  1.750000               1.0  0.061224         inf
# 33  0.142857    1.000000  1.750000               1.0  0.061224         inf
# 5   0.142857    1.000000  1.166667               1.0  0.020408         inf
# 24  0.142857    1.000000  1.166667               1.0  0.020408         inf
# 26  0.142857    1.000000  1.166667               1.0  0.020408         inf
# 8   0.142857    1.000000  1.000000               1.0  0.000000         inf
# 14  0.142857    1.000000  1.000000               1.0  0.000000         inf
# 22  0.142857    1.000000  1.000000               1.0  0.000000         inf
# 31  0.142857    1.000000  1.000000               1.0  0.000000         inf
# 13  0.142857    0.250000  1.750000               1.0  0.061224    1.142857
# 32  0.142857    0.250000  1.750000               1.0  0.061224    1.142857
# 35  0.142857    0.250000  1.750000               1.0  0.061224    1.142857
# 4   0.142857    0.166667  1.166667               1.0  0.020408    1.028571
# 23  0.142857    0.166667  1.166667               1.0  0.020408    1.028571
# 25  0.142857    0.166667  1.166667               1.0  0.020408    1.028571
# 9   0.142857    0.142857  1.000000               1.0  0.000000    1.000000
# 15  0.142857    0.142857  1.000000               1.0  0.000000    1.000000
# 27  0.142857    0.142857  1.000000               1.0  0.000000    1.000000
# 34  0.142857    0.142857  1.000000               1.0  0.000000    1.000000
#
#     zhangs_metric   jaccard  certainty  kulczynski       merged_items
# 6        0.000000  0.857143   0.000000    0.928571         剧情合理性|角色表现
# 7        0.000000  0.857143   0.000000    0.928571         角色表现|剧情合理性
# 11       0.000000  0.571429   0.000000    0.785714          台词质量|角色表现
# 10       0.000000  0.571429   0.000000    0.785714          角色表现|台词质量
# 28       0.000000  0.428571   0.000000    0.714286    剧情合理性|台词质量|角色表现
# 29       0.000000  0.428571   0.000000    0.714286    角色表现|剧情合理性|台词质量
# 1        0.200000  0.333333   1.000000    0.666667          nan|剧情合理性
# 18       0.200000  0.333333   1.000000    0.666667     nan|角色表现|剧情合理性
# 21       0.200000  0.333333   1.000000    0.666667     nan|剧情合理性|角色表现
# 3        0.000000  0.285714   0.000000    0.642857           nan|角色表现
# 17       0.000000  0.285714   0.000000    0.642857     剧情合理性|nan|角色表现
# 0        1.000000  0.333333   0.066667    0.666667          剧情合理性|nan
# 16       1.000000  0.333333   0.066667    0.666667     剧情合理性|角色表现|nan
# 19       1.000000  0.333333   0.066667    0.666667     剧情合理性|nan|角色表现
# 2        0.000000  0.285714   0.000000    0.642857           角色表现|nan
# 20       0.000000  0.285714   0.000000    0.642857     角色表现|剧情合理性|nan
# 12       0.500000  0.250000   1.000000    0.625000         音效与配乐|台词质量
# 30       0.500000  0.250000   1.000000    0.625000    音效与配乐|角色表现|台词质量
# 33       0.500000  0.250000   1.000000    0.625000    音效与配乐|角色表现|台词质量
# 5        0.166667  0.166667   1.000000    0.583333       动作场面呈现|剧情合理性
# 24       0.166667  0.166667   1.000000    0.583333  动作场面呈现|角色表现|剧情合理性
# 26       0.166667  0.166667   1.000000    0.583333  动作场面呈现|剧情合理性|角色表现
# 8        0.000000  0.142857   0.000000    0.571429        动作场面呈现|角色表现
# 14       0.000000  0.142857   0.000000    0.571429         音效与配乐|角色表现
# 22       0.000000  0.142857   0.000000    0.571429  剧情合理性|动作场面呈现|角色表现
# 31       0.000000  0.142857   0.000000    0.571429    音效与配乐|台词质量|角色表现
# 13       1.000000  0.250000   0.125000    0.625000         台词质量|音效与配乐
# 32       1.000000  0.250000   0.125000    0.625000    角色表现|台词质量|音效与配乐
# 35       1.000000  0.250000   0.125000    0.625000    台词质量|音效与配乐|角色表现
# 4        1.000000  0.166667   0.027778    0.583333       剧情合理性|动作场面呈现
# 23       1.000000  0.166667   0.027778    0.583333  剧情合理性|角色表现|动作场面呈现
# 25       1.000000  0.166667   0.027778    0.583333  剧情合理性|动作场面呈现|角色表现
# 9        0.000000  0.142857   0.000000    0.571429        角色表现|动作场面呈现
# 15       0.000000  0.142857   0.000000    0.571429         角色表现|音效与配乐
# 27       0.000000  0.142857   0.000000    0.571429  角色表现|剧情合理性|动作场面呈现
# 34       0.000000  0.142857   0.000000    0.571429    角色表现|音效与配乐|台词质量
# 第74集关联规则：
#       antecedents    consequents  antecedent support  consequent support  \
# 5          (叙事节奏)         (角色表现)            0.333333            0.888889
# 4          (角色表现)         (叙事节奏)            0.888889            0.333333
# 19         (台词质量)    (nan, 角色表现)            0.222222            0.666667
# 1          (台词质量)          (nan)            0.222222            0.777778
# 15   (角色表现, 台词质量)          (nan)            0.222222            0.777778
# 7          (台词质量)         (角色表现)            0.222222            0.888889
# 11    (nan, 叙事节奏)         (角色表现)            0.222222            0.888889
# 16    (nan, 台词质量)         (角色表现)            0.222222            0.888889
# 13         (叙事节奏)    (nan, 角色表现)            0.333333            0.666667
# 14    (nan, 角色表现)         (台词质量)            0.666667            0.222222
# 10    (nan, 角色表现)         (叙事节奏)            0.666667            0.333333
# 0           (nan)         (台词质量)            0.777778            0.222222
# 18          (nan)   (角色表现, 台词质量)            0.777778            0.222222
# 6          (角色表现)         (台词质量)            0.888889            0.222222
# 12         (角色表现)    (nan, 叙事节奏)            0.888889            0.222222
# 17         (角色表现)    (nan, 台词质量)            0.888889            0.222222
# 26         (文化深度)  (剧情合理性, 角色表现)            0.111111            0.444444
# 3          (文化深度)        (剧情合理性)            0.111111            0.555556
# 24   (文化深度, 角色表现)        (剧情合理性)            0.111111            0.555556
# 8          (文化深度)         (角色表现)            0.111111            0.888889
# 20  (剧情合理性, 叙事节奏)         (角色表现)            0.111111            0.888889
# 22  (剧情合理性, 文化深度)         (角色表现)            0.111111            0.888889
# 23  (剧情合理性, 角色表现)         (文化深度)            0.444444            0.111111
# 2         (剧情合理性)         (文化深度)            0.555556            0.111111
# 25        (剧情合理性)   (文化深度, 角色表现)            0.555556            0.111111
# 9          (角色表现)         (文化深度)            0.888889            0.111111
# 21         (角色表现)  (剧情合理性, 叙事节奏)            0.888889            0.111111
# 27         (角色表现)  (剧情合理性, 文化深度)            0.888889            0.111111
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 5   0.333333    1.000000  1.125000               1.0  0.037037         inf
# 4   0.333333    0.375000  1.125000               1.0  0.037037    1.066667
# 19  0.222222    1.000000  1.500000               1.0  0.074074         inf
# 1   0.222222    1.000000  1.285714               1.0  0.049383         inf
# 15  0.222222    1.000000  1.285714               1.0  0.049383         inf
# 7   0.222222    1.000000  1.125000               1.0  0.024691         inf
# 11  0.222222    1.000000  1.125000               1.0  0.024691         inf
# 16  0.222222    1.000000  1.125000               1.0  0.024691         inf
# 13  0.222222    0.666667  1.000000               1.0  0.000000    1.000000
# 14  0.222222    0.333333  1.500000               1.0  0.074074    1.166667
# 10  0.222222    0.333333  1.000000               1.0  0.000000    1.000000
# 0   0.222222    0.285714  1.285714               1.0  0.049383    1.088889
# 18  0.222222    0.285714  1.285714               1.0  0.049383    1.088889
# 6   0.222222    0.250000  1.125000               1.0  0.024691    1.037037
# 12  0.222222    0.250000  1.125000               1.0  0.024691    1.037037
# 17  0.222222    0.250000  1.125000               1.0  0.024691    1.037037
# 26  0.111111    1.000000  2.250000               1.0  0.061728         inf
# 3   0.111111    1.000000  1.800000               1.0  0.049383         inf
# 24  0.111111    1.000000  1.800000               1.0  0.049383         inf
# 8   0.111111    1.000000  1.125000               1.0  0.012346         inf
# 20  0.111111    1.000000  1.125000               1.0  0.012346         inf
# 22  0.111111    1.000000  1.125000               1.0  0.012346         inf
# 23  0.111111    0.250000  2.250000               1.0  0.061728    1.185185
# 2   0.111111    0.200000  1.800000               1.0  0.049383    1.111111
# 25  0.111111    0.200000  1.800000               1.0  0.049383    1.111111
# 9   0.111111    0.125000  1.125000               1.0  0.012346    1.015873
# 21  0.111111    0.125000  1.125000               1.0  0.012346    1.015873
# 27  0.111111    0.125000  1.125000               1.0  0.012346    1.015873
#
#     zhangs_metric   jaccard  certainty  kulczynski     merged_items
# 5        0.166667  0.375000   1.000000    0.687500        叙事节奏|角色表现
# 4        1.000000  0.375000   0.062500    0.687500        角色表现|叙事节奏
# 19       0.428571  0.333333   1.000000    0.666667    台词质量|nan|角色表现
# 1        0.285714  0.285714   1.000000    0.642857         台词质量|nan
# 15       0.285714  0.285714   1.000000    0.642857    角色表现|台词质量|nan
# 7        0.142857  0.250000   1.000000    0.625000        台词质量|角色表现
# 11       0.142857  0.250000   1.000000    0.625000    nan|叙事节奏|角色表现
# 16       0.142857  0.250000   1.000000    0.625000    nan|台词质量|角色表现
# 13       0.000000  0.285714   0.000000    0.500000    叙事节奏|nan|角色表现
# 14       1.000000  0.333333   0.142857    0.666667    nan|角色表现|台词质量
# 10       0.000000  0.285714   0.000000    0.500000    nan|角色表现|叙事节奏
# 0        1.000000  0.285714   0.081633    0.642857         nan|台词质量
# 18       1.000000  0.285714   0.081633    0.642857    nan|角色表现|台词质量
# 6        1.000000  0.250000   0.035714    0.625000        角色表现|台词质量
# 12       1.000000  0.250000   0.035714    0.625000    角色表现|nan|叙事节奏
# 17       1.000000  0.250000   0.035714    0.625000    角色表现|nan|台词质量
# 26       0.625000  0.250000   1.000000    0.625000  文化深度|剧情合理性|角色表现
# 3        0.500000  0.200000   1.000000    0.600000       文化深度|剧情合理性
# 24       0.500000  0.200000   1.000000    0.600000  文化深度|角色表现|剧情合理性
# 8        0.125000  0.125000   1.000000    0.562500        文化深度|角色表现
# 20       0.125000  0.125000   1.000000    0.562500  剧情合理性|叙事节奏|角色表现
# 22       0.125000  0.125000   1.000000    0.562500  剧情合理性|文化深度|角色表现
# 23       1.000000  0.250000   0.156250    0.625000  剧情合理性|角色表现|文化深度
# 2        1.000000  0.200000   0.100000    0.600000       剧情合理性|文化深度
# 25       1.000000  0.200000   0.100000    0.600000  剧情合理性|文化深度|角色表现
# 9        1.000000  0.125000   0.015625    0.562500        角色表现|文化深度
# 21       1.000000  0.125000   0.015625    0.562500  角色表现|剧情合理性|叙事节奏
# 27       1.000000  0.125000   0.015625    0.562500  角色表现|剧情合理性|文化深度
# 第75集关联规则：
#          antecedents       consequents  antecedent support  \
# 10           (剧情合理性)            (角色表现)            0.666667
# 11            (角色表现)           (剧情合理性)            0.833333
# 20      (剧情合理性, nan)            (角色表现)            0.333333
# 21       (nan, 角色表现)           (剧情合理性)            0.500000
# 22           (剧情合理性)       (nan, 角色表现)            0.666667
# 23            (角色表现)      (剧情合理性, nan)            0.833333
# 12          (动作场面呈现)          (服化道匹配度)            0.166667
# 13          (服化道匹配度)          (动作场面呈现)            0.166667
# 24     (动作场面呈现, nan)          (服化道匹配度)            0.166667
# 26     (服化道匹配度, nan)          (动作场面呈现)            0.166667
# 27          (动作场面呈现)     (服化道匹配度, nan)            0.166667
# 29          (服化道匹配度)     (动作场面呈现, nan)            0.166667
# 33            (文化深度)       (角色表现, nan)            0.166667
# 0           (动作场面呈现)             (nan)            0.166667
# 2             (文化深度)             (nan)            0.166667
# 4           (服化道匹配度)             (nan)            0.166667
# 7             (叙事节奏)           (剧情合理性)            0.166667
# 9             (台词质量)           (剧情合理性)            0.166667
# 25  (动作场面呈现, 服化道匹配度)             (nan)            0.166667
# 31      (文化深度, 角色表现)             (nan)            0.166667
# 38      (角色表现, 叙事节奏)           (剧情合理性)            0.166667
# 41            (叙事节奏)     (剧情合理性, 角色表现)            0.166667
# 44      (角色表现, 台词质量)           (剧情合理性)            0.166667
# 47            (台词质量)     (剧情合理性, 角色表现)            0.166667
# 15            (叙事节奏)            (角色表现)            0.166667
# 17            (台词质量)            (角色表现)            0.166667
# 18            (文化深度)            (角色表现)            0.166667
# 30       (文化深度, nan)            (角色表现)            0.166667
# 37     (剧情合理性, 叙事节奏)            (角色表现)            0.166667
# 43     (剧情合理性, 台词质量)            (角色表现)            0.166667
# 32       (角色表现, nan)            (文化深度)            0.500000
# 1              (nan)          (动作场面呈现)            0.666667
# 3              (nan)            (文化深度)            0.666667
# 5              (nan)          (服化道匹配度)            0.666667
# 6            (剧情合理性)            (叙事节奏)            0.666667
# 8            (剧情合理性)            (台词质量)            0.666667
# 28             (nan)  (动作场面呈现, 服化道匹配度)            0.666667
# 34             (nan)      (文化深度, 角色表现)            0.666667
# 36     (剧情合理性, 角色表现)            (叙事节奏)            0.666667
# 39           (剧情合理性)      (角色表现, 叙事节奏)            0.666667
# 42     (剧情合理性, 角色表现)            (台词质量)            0.666667
# 45           (剧情合理性)      (角色表现, 台词质量)            0.666667
# 14            (角色表现)            (叙事节奏)            0.833333
# 16            (角色表现)            (台词质量)            0.833333
# 19            (角色表现)            (文化深度)            0.833333
# 35            (角色表现)       (文化深度, nan)            0.833333
# 40            (角色表现)     (剧情合理性, 叙事节奏)            0.833333
# 46            (角色表现)     (剧情合理性, 台词质量)            0.833333
#
#     consequent support   support  confidence  lift  representativity  \
# 10            0.833333  0.666667    1.000000   1.2               1.0
# 11            0.666667  0.666667    0.800000   1.2               1.0
# 20            0.833333  0.333333    1.000000   1.2               1.0
# 21            0.666667  0.333333    0.666667   1.0               1.0
# 22            0.500000  0.333333    0.500000   1.0               1.0
# 23            0.333333  0.333333    0.400000   1.2               1.0
# 12            0.166667  0.166667    1.000000   6.0               1.0
# 13            0.166667  0.166667    1.000000   6.0               1.0
# 24            0.166667  0.166667    1.000000   6.0               1.0
# 26            0.166667  0.166667    1.000000   6.0               1.0
# 27            0.166667  0.166667    1.000000   6.0               1.0
# 29            0.166667  0.166667    1.000000   6.0               1.0
# 33            0.500000  0.166667    1.000000   2.0               1.0
# 0             0.666667  0.166667    1.000000   1.5               1.0
# 2             0.666667  0.166667    1.000000   1.5               1.0
# 4             0.666667  0.166667    1.000000   1.5               1.0
# 7             0.666667  0.166667    1.000000   1.5               1.0
# 9             0.666667  0.166667    1.000000   1.5               1.0
# 25            0.666667  0.166667    1.000000   1.5               1.0
# 31            0.666667  0.166667    1.000000   1.5               1.0
# 38            0.666667  0.166667    1.000000   1.5               1.0
# 41            0.666667  0.166667    1.000000   1.5               1.0
# 44            0.666667  0.166667    1.000000   1.5               1.0
# 47            0.666667  0.166667    1.000000   1.5               1.0
# 15            0.833333  0.166667    1.000000   1.2               1.0
# 17            0.833333  0.166667    1.000000   1.2               1.0
# 18            0.833333  0.166667    1.000000   1.2               1.0
# 30            0.833333  0.166667    1.000000   1.2               1.0
# 37            0.833333  0.166667    1.000000   1.2               1.0
# 43            0.833333  0.166667    1.000000   1.2               1.0
# 32            0.166667  0.166667    0.333333   2.0               1.0
# 1             0.166667  0.166667    0.250000   1.5               1.0
# 3             0.166667  0.166667    0.250000   1.5               1.0
# 5             0.166667  0.166667    0.250000   1.5               1.0
# 6             0.166667  0.166667    0.250000   1.5               1.0
# 8             0.166667  0.166667    0.250000   1.5               1.0
# 28            0.166667  0.166667    0.250000   1.5               1.0
# 34            0.166667  0.166667    0.250000   1.5               1.0
# 36            0.166667  0.166667    0.250000   1.5               1.0
# 39            0.166667  0.166667    0.250000   1.5               1.0
# 42            0.166667  0.166667    0.250000   1.5               1.0
# 45            0.166667  0.166667    0.250000   1.5               1.0
# 14            0.166667  0.166667    0.200000   1.2               1.0
# 16            0.166667  0.166667    0.200000   1.2               1.0
# 19            0.166667  0.166667    0.200000   1.2               1.0
# 35            0.166667  0.166667    0.200000   1.2               1.0
# 40            0.166667  0.166667    0.200000   1.2               1.0
# 46            0.166667  0.166667    0.200000   1.2               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 10  0.111111         inf           0.50  0.800000       1.00    0.900000
# 11  0.111111    1.666667           1.00  0.800000       0.40    0.900000
# 20  0.055556         inf           0.25  0.400000       1.00    0.700000
# 21  0.000000    1.000000           0.00  0.400000       0.00    0.583333
# 22  0.000000    1.000000           0.00  0.400000       0.00    0.583333
# 23  0.055556    1.111111           1.00  0.400000       0.10    0.700000
# 12  0.138889         inf           1.00  1.000000       1.00    1.000000
# 13  0.138889         inf           1.00  1.000000       1.00    1.000000
# 24  0.138889         inf           1.00  1.000000       1.00    1.000000
# 26  0.138889         inf           1.00  1.000000       1.00    1.000000
# 27  0.138889         inf           1.00  1.000000       1.00    1.000000
# 29  0.138889         inf           1.00  1.000000       1.00    1.000000
# 33  0.083333         inf           0.60  0.333333       1.00    0.666667
# 0   0.055556         inf           0.40  0.250000       1.00    0.625000
# 2   0.055556         inf           0.40  0.250000       1.00    0.625000
# 4   0.055556         inf           0.40  0.250000       1.00    0.625000
# 7   0.055556         inf           0.40  0.250000       1.00    0.625000
# 9   0.055556         inf           0.40  0.250000       1.00    0.625000
# 25  0.055556         inf           0.40  0.250000       1.00    0.625000
# 31  0.055556         inf           0.40  0.250000       1.00    0.625000
# 38  0.055556         inf           0.40  0.250000       1.00    0.625000
# 41  0.055556         inf           0.40  0.250000       1.00    0.625000
# 44  0.055556         inf           0.40  0.250000       1.00    0.625000
# 47  0.055556         inf           0.40  0.250000       1.00    0.625000
# 15  0.027778         inf           0.20  0.200000       1.00    0.600000
# 17  0.027778         inf           0.20  0.200000       1.00    0.600000
# 18  0.027778         inf           0.20  0.200000       1.00    0.600000
# 30  0.027778         inf           0.20  0.200000       1.00    0.600000
# 37  0.027778         inf           0.20  0.200000       1.00    0.600000
# 43  0.027778         inf           0.20  0.200000       1.00    0.600000
# 32  0.083333    1.250000           1.00  0.333333       0.20    0.666667
# 1   0.055556    1.111111           1.00  0.250000       0.10    0.625000
# 3   0.055556    1.111111           1.00  0.250000       0.10    0.625000
# 5   0.055556    1.111111           1.00  0.250000       0.10    0.625000
# 6   0.055556    1.111111           1.00  0.250000       0.10    0.625000
# 8   0.055556    1.111111           1.00  0.250000       0.10    0.625000
# 28  0.055556    1.111111           1.00  0.250000       0.10    0.625000
# 34  0.055556    1.111111           1.00  0.250000       0.10    0.625000
# 36  0.055556    1.111111           1.00  0.250000       0.10    0.625000
# 39  0.055556    1.111111           1.00  0.250000       0.10    0.625000
# 42  0.055556    1.111111           1.00  0.250000       0.10    0.625000
# 45  0.055556    1.111111           1.00  0.250000       0.10    0.625000
# 14  0.027778    1.041667           1.00  0.200000       0.04    0.600000
# 16  0.027778    1.041667           1.00  0.200000       0.04    0.600000
# 19  0.027778    1.041667           1.00  0.200000       0.04    0.600000
# 35  0.027778    1.041667           1.00  0.200000       0.04    0.600000
# 40  0.027778    1.041667           1.00  0.200000       0.04    0.600000
# 46  0.027778    1.041667           1.00  0.200000       0.04    0.600000
#
#          merged_items
# 10         剧情合理性|角色表现
# 11         角色表现|剧情合理性
# 20     剧情合理性|nan|角色表现
# 21     nan|角色表现|剧情合理性
# 22     剧情合理性|nan|角色表现
# 23     角色表现|剧情合理性|nan
# 12      动作场面呈现|服化道匹配度
# 13      服化道匹配度|动作场面呈现
# 24  动作场面呈现|nan|服化道匹配度
# 26  服化道匹配度|nan|动作场面呈现
# 27  动作场面呈现|服化道匹配度|nan
# 29  服化道匹配度|动作场面呈现|nan
# 33      文化深度|角色表现|nan
# 0          动作场面呈现|nan
# 2            文化深度|nan
# 4          服化道匹配度|nan
# 7          叙事节奏|剧情合理性
# 9          台词质量|剧情合理性
# 25  动作场面呈现|服化道匹配度|nan
# 31      文化深度|角色表现|nan
# 38    角色表现|叙事节奏|剧情合理性
# 41    叙事节奏|剧情合理性|角色表现
# 44    角色表现|台词质量|剧情合理性
# 47    台词质量|剧情合理性|角色表现
# 15          叙事节奏|角色表现
# 17          台词质量|角色表现
# 18          文化深度|角色表现
# 30      文化深度|nan|角色表现
# 37    剧情合理性|叙事节奏|角色表现
# 43    剧情合理性|台词质量|角色表现
# 32      角色表现|nan|文化深度
# 1          nan|动作场面呈现
# 3            nan|文化深度
# 5          nan|服化道匹配度
# 6          剧情合理性|叙事节奏
# 8          剧情合理性|台词质量
# 28  nan|动作场面呈现|服化道匹配度
# 34      nan|文化深度|角色表现
# 36    剧情合理性|角色表现|叙事节奏
# 39    剧情合理性|角色表现|叙事节奏
# 42    剧情合理性|角色表现|台词质量
# 45    剧情合理性|角色表现|台词质量
# 14          角色表现|叙事节奏
# 16          角色表现|台词质量
# 19          角色表现|文化深度
# 35      角色表现|文化深度|nan
# 40    角色表现|剧情合理性|叙事节奏
# 46    角色表现|剧情合理性|台词质量
# 第76集关联规则：
#       antecedents      consequents  antecedent support  consequent support  \
# 10        (剧情合理性)           (角色表现)            0.795918            1.000000
# 11         (角色表现)          (剧情合理性)            1.000000            0.795918
# 22         (文化深度)           (角色表现)            0.408163            1.000000
# 23         (角色表现)           (文化深度)            1.000000            0.408163
# 56  (剧情合理性, 文化深度)           (角色表现)            0.346939            1.000000
# ..            ...              ...                 ...                 ...
# 63         (角色表现)  (剧情合理性, 服化道匹配度)            1.000000            0.020408
# 69         (角色表现)   (动作场面呈现, 叙事节奏)            1.000000            0.020408
# 71         (角色表现)     (文化深度, 叙事节奏)            1.000000            0.020408
# 73         (角色表现)   (服化道匹配度, 叙事节奏)            1.000000            0.020408
# 78         (角色表现)    (音效与配乐, 叙事节奏)            1.000000            0.020408
#
#      support  confidence  lift  representativity  leverage  conviction  \
# 10  0.795918    1.000000   1.0               1.0       0.0         inf
# 11  0.795918    0.795918   1.0               1.0       0.0         1.0
# 22  0.408163    1.000000   1.0               1.0       0.0         inf
# 23  0.408163    0.408163   1.0               1.0       0.0         1.0
# 56  0.346939    1.000000   1.0               1.0       0.0         inf
# ..       ...         ...   ...               ...       ...         ...
# 63  0.020408    0.020408   1.0               1.0       0.0         1.0
# 69  0.020408    0.020408   1.0               1.0       0.0         1.0
# 71  0.020408    0.020408   1.0               1.0       0.0         1.0
# 73  0.020408    0.020408   1.0               1.0       0.0         1.0
# 78  0.020408    0.020408   1.0               1.0       0.0         1.0
#
#     zhangs_metric   jaccard  certainty  kulczynski       merged_items
# 10            0.0  0.795918        0.0    0.897959         剧情合理性|角色表现
# 11            0.0  0.795918        0.0    0.897959         角色表现|剧情合理性
# 22            0.0  0.408163        0.0    0.704082          文化深度|角色表现
# 23            0.0  0.408163        0.0    0.704082          角色表现|文化深度
# 56            0.0  0.346939        0.0    0.673469    剧情合理性|文化深度|角色表现
# ..            ...       ...        ...         ...                ...
# 63            0.0  0.020408        0.0    0.510204  角色表现|剧情合理性|服化道匹配度
# 69            0.0  0.020408        0.0    0.510204   角色表现|动作场面呈现|叙事节奏
# 71            0.0  0.020408        0.0    0.510204     角色表现|文化深度|叙事节奏
# 73            0.0  0.020408        0.0    0.510204   角色表现|服化道匹配度|叙事节奏
# 78            0.0  0.020408        0.0    0.510204    角色表现|音效与配乐|叙事节奏
#
# [80 rows x 15 columns]
# 第77集关联规则：
#        antecedents     consequents  antecedent support  consequent support  \
# 8           (文化深度)          (角色表现)            0.384615            0.884615
# 9           (角色表现)          (文化深度)            0.884615            0.384615
# 32   (剧情合理性, 文化深度)          (角色表现)            0.346154            0.884615
# 36          (文化深度)   (剧情合理性, 角色表现)            0.384615            0.730769
# 7           (文化深度)         (剧情合理性)            0.384615            0.846154
# 34    (文化深度, 角色表现)         (剧情合理性)            0.384615            0.846154
# 33   (剧情合理性, 角色表现)          (文化深度)            0.730769            0.384615
# 6          (剧情合理性)          (文化深度)            0.846154            0.384615
# 35         (剧情合理性)    (文化深度, 角色表现)            0.846154            0.384615
# 37          (角色表现)   (剧情合理性, 文化深度)            0.884615            0.346154
# 5           (叙事节奏)         (剧情合理性)            0.230769            0.846154
# 4          (剧情合理性)          (叙事节奏)            0.846154            0.230769
# 30    (角色表现, 叙事节奏)         (剧情合理性)            0.153846            0.846154
# 31         (剧情合理性)    (角色表现, 叙事节奏)            0.846154            0.153846
# 27        (服化道匹配度)     (角色表现, nan)            0.076923            0.384615
# 1           (台词质量)           (nan)            0.076923            0.500000
# 2         (服化道匹配度)           (nan)            0.076923            0.500000
# 25  (服化道匹配度, 角色表现)           (nan)            0.076923            0.500000
# 12     (nan, 叙事节奏)         (剧情合理性)            0.076923            0.846154
# 10        (服化道匹配度)          (角色表现)            0.076923            0.884615
# 24   (服化道匹配度, nan)          (角色表现)            0.076923            0.884615
# 26     (角色表现, nan)        (服化道匹配度)            0.384615            0.076923
# 0            (nan)          (台词质量)            0.500000            0.076923
# 3            (nan)        (服化道匹配度)            0.500000            0.076923
# 28           (nan)  (服化道匹配度, 角色表现)            0.500000            0.076923
# 13         (剧情合理性)     (nan, 叙事节奏)            0.846154            0.076923
# 11          (角色表现)        (服化道匹配度)            0.884615            0.076923
# 29          (角色表现)   (服化道匹配度, nan)            0.884615            0.076923
# 15   (剧情合理性, 台词质量)           (nan)            0.038462            0.500000
# 19    (角色表现, 台词质量)           (nan)            0.038462            0.500000
# 22     (文化深度, nan)          (角色表现)            0.038462            0.884615
# 17          (台词质量)    (剧情合理性, nan)            0.076923            0.346154
# 21          (台词质量)     (nan, 角色表现)            0.076923            0.384615
# 14    (剧情合理性, nan)          (台词质量)            0.346154            0.076923
# 18     (nan, 角色表现)          (台词质量)            0.384615            0.076923
# 16           (nan)   (剧情合理性, 台词质量)            0.500000            0.038462
# 20           (nan)    (角色表现, 台词质量)            0.500000            0.038462
# 23          (角色表现)     (文化深度, nan)            0.884615            0.038462
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 8   0.384615    1.000000  1.130435               1.0  0.044379         inf
# 9   0.384615    0.434783  1.130435               1.0  0.044379    1.088757
# 32  0.346154    1.000000  1.130435               1.0  0.039941         inf
# 36  0.346154    0.900000  1.231579               1.0  0.065089    2.692308
# 7   0.346154    0.900000  1.063636               1.0  0.020710    1.538462
# 34  0.346154    0.900000  1.063636               1.0  0.020710    1.538462
# 33  0.346154    0.473684  1.231579               1.0  0.065089    1.169231
# 6   0.346154    0.409091  1.063636               1.0  0.020710    1.041420
# 35  0.346154    0.409091  1.063636               1.0  0.020710    1.041420
# 37  0.346154    0.391304  1.130435               1.0  0.039941    1.074176
# 5   0.230769    1.000000  1.181818               1.0  0.035503         inf
# 4   0.230769    0.272727  1.181818               1.0  0.035503    1.057692
# 30  0.153846    1.000000  1.181818               1.0  0.023669         inf
# 31  0.153846    0.181818  1.181818               1.0  0.023669    1.034188
# 27  0.076923    1.000000  2.600000               1.0  0.047337         inf
# 1   0.076923    1.000000  2.000000               1.0  0.038462         inf
# 2   0.076923    1.000000  2.000000               1.0  0.038462         inf
# 25  0.076923    1.000000  2.000000               1.0  0.038462         inf
# 12  0.076923    1.000000  1.181818               1.0  0.011834         inf
# 10  0.076923    1.000000  1.130435               1.0  0.008876         inf
# 24  0.076923    1.000000  1.130435               1.0  0.008876         inf
# 26  0.076923    0.200000  2.600000               1.0  0.047337    1.153846
# 0   0.076923    0.153846  2.000000               1.0  0.038462    1.090909
# 3   0.076923    0.153846  2.000000               1.0  0.038462    1.090909
# 28  0.076923    0.153846  2.000000               1.0  0.038462    1.090909
# 13  0.076923    0.090909  1.181818               1.0  0.011834    1.015385
# 11  0.076923    0.086957  1.130435               1.0  0.008876    1.010989
# 29  0.076923    0.086957  1.130435               1.0  0.008876    1.010989
# 15  0.038462    1.000000  2.000000               1.0  0.019231         inf
# 19  0.038462    1.000000  2.000000               1.0  0.019231         inf
# 22  0.038462    1.000000  1.130435               1.0  0.004438         inf
# 17  0.038462    0.500000  1.444444               1.0  0.011834    1.307692
# 21  0.038462    0.500000  1.300000               1.0  0.008876    1.230769
# 14  0.038462    0.111111  1.444444               1.0  0.011834    1.038462
# 18  0.038462    0.100000  1.300000               1.0  0.008876    1.025641
# 16  0.038462    0.076923  2.000000               1.0  0.019231    1.041667
# 20  0.038462    0.076923  2.000000               1.0  0.019231    1.041667
# 23  0.038462    0.043478  1.130435               1.0  0.004438    1.005245
#
#     zhangs_metric   jaccard  certainty  kulczynski     merged_items
# 8        0.187500  0.434783   1.000000    0.717391        文化深度|角色表现
# 9        1.000000  0.434783   0.081522    0.717391        角色表现|文化深度
# 32       0.176471  0.391304   1.000000    0.695652  剧情合理性|文化深度|角色表现
# 36       0.305556  0.450000   0.628571    0.686842  文化深度|剧情合理性|角色表现
# 7        0.097222  0.391304   0.350000    0.654545       文化深度|剧情合理性
# 34       0.097222  0.391304   0.350000    0.654545  文化深度|角色表现|剧情合理性
# 33       0.698413  0.450000   0.144737    0.686842  剧情合理性|角色表现|文化深度
# 6        0.388889  0.391304   0.039773    0.654545       剧情合理性|文化深度
# 35       0.388889  0.391304   0.039773    0.654545  剧情合理性|文化深度|角色表现
# 37       1.000000  0.391304   0.069054    0.695652  角色表现|剧情合理性|文化深度
# 5        0.200000  0.272727   1.000000    0.636364       叙事节奏|剧情合理性
# 4        1.000000  0.272727   0.054545    0.636364       剧情合理性|叙事节奏
# 30       0.181818  0.181818   1.000000    0.590909  角色表现|叙事节奏|剧情合理性
# 31       1.000000  0.181818   0.033058    0.590909  剧情合理性|角色表现|叙事节奏
# 27       0.666667  0.200000   1.000000    0.600000  服化道匹配度|角色表现|nan
# 1        0.541667  0.153846   1.000000    0.576923         台词质量|nan
# 2        0.541667  0.153846   1.000000    0.576923       服化道匹配度|nan
# 25       0.541667  0.153846   1.000000    0.576923  服化道匹配度|角色表现|nan
# 12       0.166667  0.090909   1.000000    0.545455   nan|叙事节奏|剧情合理性
# 10       0.125000  0.086957   1.000000    0.543478      服化道匹配度|角色表现
# 24       0.125000  0.086957   1.000000    0.543478  服化道匹配度|nan|角色表现
# 26       1.000000  0.200000   0.133333    0.600000  角色表现|nan|服化道匹配度
# 0        1.000000  0.153846   0.083333    0.576923         nan|台词质量
# 3        1.000000  0.153846   0.083333    0.576923       nan|服化道匹配度
# 28       1.000000  0.153846   0.083333    0.576923  nan|服化道匹配度|角色表现
# 13       1.000000  0.090909   0.015152    0.545455   剧情合理性|nan|叙事节奏
# 11       1.000000  0.086957   0.010870    0.543478      角色表现|服化道匹配度
# 29       1.000000  0.086957   0.010870    0.543478  角色表现|服化道匹配度|nan
# 15       0.520000  0.076923   1.000000    0.538462   剧情合理性|台词质量|nan
# 19       0.520000  0.076923   1.000000    0.538462    角色表现|台词质量|nan
# 22       0.120000  0.043478   1.000000    0.521739    文化深度|nan|角色表现
# 17       0.333333  0.100000   0.235294    0.305556   台词质量|剧情合理性|nan
# 21       0.250000  0.090909   0.187500    0.300000    台词质量|nan|角色表现
# 14       0.470588  0.100000   0.037037    0.305556   剧情合理性|nan|台词质量
# 18       0.375000  0.090909   0.025000    0.300000    nan|角色表现|台词质量
# 16       1.000000  0.076923   0.040000    0.538462   nan|剧情合理性|台词质量
# 20       1.000000  0.076923   0.040000    0.538462    nan|角色表现|台词质量
# 23       1.000000  0.043478   0.005217    0.521739    角色表现|文化深度|nan
# C:\Users\lenovo\AppData\Roaming\Python\Python311\site-packages\mlxtend\frequent_patterns\association_rules.py:186: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)
# C:\Users\lenovo\AppData\Roaming\Python\Python311\site-packages\mlxtend\frequent_patterns\association_rules.py:186: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)
# 第78集关联规则：
#         antecedents      consequents  antecedent support  consequent support  \
# 8           (剧情合理性)           (角色表现)            0.666667            1.000000
# 14           (文化深度)           (角色表现)            0.666667            1.000000
# 9            (角色表现)          (剧情合理性)            1.000000            0.666667
# 15           (角色表现)           (文化深度)            1.000000            0.666667
# 3             (nan)           (角色表现)            0.444444            1.000000
# 2            (角色表现)            (nan)            1.000000            0.444444
# 18      (文化深度, nan)           (角色表现)            0.333333            1.000000
# 36    (剧情合理性, 文化深度)           (角色表现)            0.333333            1.000000
# 1             (nan)           (文化深度)            0.444444            0.666667
# 20      (角色表现, nan)           (文化深度)            0.444444            0.666667
# 22            (nan)     (文化深度, 角色表现)            0.444444            0.666667
# 0            (文化深度)            (nan)            0.666667            0.444444
# 19     (文化深度, 角色表现)            (nan)            0.666667            0.444444
# 21           (文化深度)      (角色表现, nan)            0.666667            0.444444
# 23           (角色表现)      (文化深度, nan)            1.000000            0.333333
# 37           (角色表现)    (剧情合理性, 文化深度)            1.000000            0.333333
# 5          (动作场面呈现)          (剧情合理性)            0.111111            0.666667
# 7            (叙事节奏)          (剧情合理性)            0.111111            0.666667
# 26   (动作场面呈现, 角色表现)          (剧情合理性)            0.111111            0.666667
# 28         (动作场面呈现)    (剧情合理性, 角色表现)            0.111111            0.666667
# 32     (角色表现, 叙事节奏)          (剧情合理性)            0.111111            0.666667
# 35           (叙事节奏)    (剧情合理性, 角色表现)            0.111111            0.666667
# 10         (动作场面呈现)           (角色表现)            0.111111            1.000000
# 13           (叙事节奏)           (角色表现)            0.111111            1.000000
# 16     (剧情合理性, nan)           (角色表现)            0.111111            1.000000
# 24  (剧情合理性, 动作场面呈现)           (角色表现)            0.111111            1.000000
# 31    (剧情合理性, 叙事节奏)           (角色表现)            0.111111            1.000000
# 4           (剧情合理性)         (动作场面呈现)            0.666667            0.111111
# 6           (剧情合理性)           (叙事节奏)            0.666667            0.111111
# 25    (剧情合理性, 角色表现)         (动作场面呈现)            0.666667            0.111111
# 27          (剧情合理性)   (动作场面呈现, 角色表现)            0.666667            0.111111
# 30    (剧情合理性, 角色表现)           (叙事节奏)            0.666667            0.111111
# 33          (剧情合理性)     (角色表现, 叙事节奏)            0.666667            0.111111
# 11           (角色表现)         (动作场面呈现)            1.000000            0.111111
# 12           (角色表现)           (叙事节奏)            1.000000            0.111111
# 17           (角色表现)     (剧情合理性, nan)            1.000000            0.111111
# 29           (角色表现)  (剧情合理性, 动作场面呈现)            1.000000            0.111111
# 34           (角色表现)    (剧情合理性, 叙事节奏)            1.000000            0.111111
#
#      support  confidence   lift  representativity  leverage  conviction  \
# 8   0.666667    1.000000  1.000               1.0  0.000000         inf
# 14  0.666667    1.000000  1.000               1.0  0.000000         inf
# 9   0.666667    0.666667  1.000               1.0  0.000000    1.000000
# 15  0.666667    0.666667  1.000               1.0  0.000000    1.000000
# 3   0.444444    1.000000  1.000               1.0  0.000000         inf
# 2   0.444444    0.444444  1.000               1.0  0.000000    1.000000
# 18  0.333333    1.000000  1.000               1.0  0.000000         inf
# 36  0.333333    1.000000  1.000               1.0  0.000000         inf
# 1   0.333333    0.750000  1.125               1.0  0.037037    1.333333
# 20  0.333333    0.750000  1.125               1.0  0.037037    1.333333
# 22  0.333333    0.750000  1.125               1.0  0.037037    1.333333
# 0   0.333333    0.500000  1.125               1.0  0.037037    1.111111
# 19  0.333333    0.500000  1.125               1.0  0.037037    1.111111
# 21  0.333333    0.500000  1.125               1.0  0.037037    1.111111
# 23  0.333333    0.333333  1.000               1.0  0.000000    1.000000
# 37  0.333333    0.333333  1.000               1.0  0.000000    1.000000
# 5   0.111111    1.000000  1.500               1.0  0.037037         inf
# 7   0.111111    1.000000  1.500               1.0  0.037037         inf
# 26  0.111111    1.000000  1.500               1.0  0.037037         inf
# 28  0.111111    1.000000  1.500               1.0  0.037037         inf
# 32  0.111111    1.000000  1.500               1.0  0.037037         inf
# 35  0.111111    1.000000  1.500               1.0  0.037037         inf
# 10  0.111111    1.000000  1.000               1.0  0.000000         inf
# 13  0.111111    1.000000  1.000               1.0  0.000000         inf
# 16  0.111111    1.000000  1.000               1.0  0.000000         inf
# 24  0.111111    1.000000  1.000               1.0  0.000000         inf
# 31  0.111111    1.000000  1.000               1.0  0.000000         inf
# 4   0.111111    0.166667  1.500               1.0  0.037037    1.066667
# 6   0.111111    0.166667  1.500               1.0  0.037037    1.066667
# 25  0.111111    0.166667  1.500               1.0  0.037037    1.066667
# 27  0.111111    0.166667  1.500               1.0  0.037037    1.066667
# 30  0.111111    0.166667  1.500               1.0  0.037037    1.066667
# 33  0.111111    0.166667  1.500               1.0  0.037037    1.066667
# 11  0.111111    0.111111  1.000               1.0  0.000000    1.000000
# 12  0.111111    0.111111  1.000               1.0  0.000000    1.000000
# 17  0.111111    0.111111  1.000               1.0  0.000000    1.000000
# 29  0.111111    0.111111  1.000               1.0  0.000000    1.000000
# 34  0.111111    0.111111  1.000               1.0  0.000000    1.000000
#
#     zhangs_metric   jaccard  certainty  kulczynski       merged_items
# 8        0.000000  0.666667     0.0000    0.833333         剧情合理性|角色表现
# 14       0.000000  0.666667     0.0000    0.833333          文化深度|角色表现
# 9        0.000000  0.666667     0.0000    0.833333         角色表现|剧情合理性
# 15       0.000000  0.666667     0.0000    0.833333          角色表现|文化深度
# 3        0.000000  0.444444     0.0000    0.722222           nan|角色表现
# 2        0.000000  0.444444     0.0000    0.722222           角色表现|nan
# 18       0.000000  0.333333     0.0000    0.666667      文化深度|nan|角色表现
# 36       0.000000  0.333333     0.0000    0.666667    剧情合理性|文化深度|角色表现
# 1        0.200000  0.428571     0.2500    0.625000           nan|文化深度
# 20       0.200000  0.428571     0.2500    0.625000      角色表现|nan|文化深度
# 22       0.200000  0.428571     0.2500    0.625000      nan|文化深度|角色表现
# 0        0.333333  0.428571     0.1000    0.625000           文化深度|nan
# 19       0.333333  0.428571     0.1000    0.625000      文化深度|角色表现|nan
# 21       0.333333  0.428571     0.1000    0.625000      文化深度|角色表现|nan
# 23       0.000000  0.333333     0.0000    0.666667      角色表现|文化深度|nan
# 37       0.000000  0.333333     0.0000    0.666667    角色表现|剧情合理性|文化深度
# 5        0.375000  0.166667     1.0000    0.583333       动作场面呈现|剧情合理性
# 7        0.375000  0.166667     1.0000    0.583333         叙事节奏|剧情合理性
# 26       0.375000  0.166667     1.0000    0.583333  动作场面呈现|角色表现|剧情合理性
# 28       0.375000  0.166667     1.0000    0.583333  动作场面呈现|剧情合理性|角色表现
# 32       0.375000  0.166667     1.0000    0.583333    角色表现|叙事节奏|剧情合理性
# 35       0.375000  0.166667     1.0000    0.583333    叙事节奏|剧情合理性|角色表现
# 10       0.000000  0.111111     0.0000    0.555556        动作场面呈现|角色表现
# 13       0.000000  0.111111     0.0000    0.555556          叙事节奏|角色表现
# 16       0.000000  0.111111     0.0000    0.555556     剧情合理性|nan|角色表现
# 24       0.000000  0.111111     0.0000    0.555556  剧情合理性|动作场面呈现|角色表现
# 31       0.000000  0.111111     0.0000    0.555556    剧情合理性|叙事节奏|角色表现
# 4        1.000000  0.166667     0.0625    0.583333       剧情合理性|动作场面呈现
# 6        1.000000  0.166667     0.0625    0.583333         剧情合理性|叙事节奏
# 25       1.000000  0.166667     0.0625    0.583333  剧情合理性|角色表现|动作场面呈现
# 27       1.000000  0.166667     0.0625    0.583333  剧情合理性|动作场面呈现|角色表现
# 30       1.000000  0.166667     0.0625    0.583333    剧情合理性|角色表现|叙事节奏
# 33       1.000000  0.166667     0.0625    0.583333    剧情合理性|角色表现|叙事节奏
# 11       0.000000  0.111111     0.0000    0.555556        角色表现|动作场面呈现
# 12       0.000000  0.111111     0.0000    0.555556          角色表现|叙事节奏
# 17       0.000000  0.111111     0.0000    0.555556     角色表现|剧情合理性|nan
# 29       0.000000  0.111111     0.0000    0.555556  角色表现|剧情合理性|动作场面呈现
# 34       0.000000  0.111111     0.0000    0.555556    角色表现|剧情合理性|叙事节奏
# 第79集关联规则：
# ...
# 19            0.058824  0.058824    1.000000  17.000000               1.0
# 10            0.176471  0.058824    1.000000   5.666667               1.0
# 16            0.176471  0.058824    1.000000   5.666667               1.0
# 0             0.411765  0.058824    1.000000   2.428571               1.0
# 17            0.411765  0.058824    1.000000   2.428571               1.0
# 24            0.764706  0.058824    1.000000   1.307692               1.0
# 34            0.764706  0.058824    1.000000   1.307692               1.0
# 36            0.823529  0.058824    1.000000   1.214286               1.0
# 27            0.294118  0.058824    0.500000   1.700000               1.0
# 3             0.411765  0.058824    0.500000   1.214286               1.0
# 23            0.411765  0.058824    0.500000   1.214286               1.0
# 11            0.058824  0.058824    0.333333   5.666667               1.0
# 21            0.058824  0.058824    0.333333   5.666667               1.0
# 22            0.117647  0.058824    0.200000   1.700000               1.0
# 1             0.058824  0.058824    0.142857   2.428571               1.0
# 20            0.058824  0.058824    0.142857   2.428571               1.0
# 2             0.117647  0.058824    0.142857   1.214286               1.0
# 26            0.117647  0.058824    0.142857   1.214286               1.0
# 25            0.058824  0.058824    0.076923   1.307692               1.0
# 35            0.058824  0.058824    0.076923   1.307692               1.0
# 37            0.058824  0.058824    0.071429   1.214286               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 9   0.017301    1.147059       0.113636  0.687500   0.128205    0.815934
# 8   0.017301    1.098039       0.151515  0.687500   0.089286    0.815934
# 5   0.024221    1.411765       0.111111  0.466667   0.291667    0.687500
# 4   0.024221    1.058824       0.333333  0.466667   0.055556    0.687500
# 7   0.031142         inf       0.214286  0.214286   1.000000    0.607143
# 6   0.031142    1.048128       1.000000  0.214286   0.045918    0.607143
# 15  0.027682         inf       0.266667  0.153846   1.000000    0.576923
# 38  0.027682         inf       0.266667  0.153846   1.000000    0.576923
# 30  0.020761         inf       0.200000  0.142857   1.000000    0.571429
# 40  0.020761         inf       0.200000  0.142857   1.000000    0.571429
# 32  0.044983    1.764706       0.464286  0.250000   0.433333    0.476190
# 12  0.034602    1.588235       0.357143  0.222222   0.370370    0.458333
# 28  0.034602    1.588235       0.357143  0.222222   0.370370    0.458333
# 42  0.003460    1.058824       0.035714  0.166667   0.055556    0.424242
# 29  0.044983    1.152941       0.650000  0.250000   0.132653    0.476190
# 13  0.034602    1.098039       0.555556  0.222222   0.089286    0.458333
# 33  0.034602    1.098039       0.555556  0.222222   0.089286    0.458333
# 39  0.003460    1.006536       0.083333  0.166667   0.006494    0.424242
# 14  0.027682    1.042781       1.000000  0.153846   0.041026    0.576923
# 43  0.027682    1.042781       1.000000  0.153846   0.041026    0.576923
# 31  0.020761    1.029412       1.000000  0.142857   0.028571    0.571429
# 41  0.020761    1.029412       1.000000  0.142857   0.028571    0.571429
# 18  0.055363         inf       1.000000  1.000000   1.000000    1.000000
# 19  0.055363         inf       1.000000  1.000000   1.000000    1.000000
# 10  0.048443         inf       0.875000  0.333333   1.000000    0.666667
# 16  0.048443         inf       0.875000  0.333333   1.000000    0.666667
# 0   0.034602         inf       0.625000  0.142857   1.000000    0.571429
# 17  0.034602         inf       0.625000  0.142857   1.000000    0.571429
# 24  0.013841         inf       0.250000  0.076923   1.000000    0.538462
# 34  0.013841         inf       0.250000  0.076923   1.000000    0.538462
# 36  0.010381         inf       0.187500  0.071429   1.000000    0.535714
# 27  0.024221    1.411765       0.466667  0.166667   0.291667    0.350000
# 3   0.010381    1.176471       0.200000  0.125000   0.150000    0.321429
# 23  0.010381    1.176471       0.200000  0.125000   0.150000    0.321429
# 11  0.048443    1.411765       1.000000  0.333333   0.291667    0.666667
# 21  0.048443    1.411765       1.000000  0.333333   0.291667    0.666667
# 22  0.024221    1.102941       0.583333  0.166667   0.093333    0.350000
# 1   0.034602    1.098039       1.000000  0.142857   0.089286    0.571429
# 20  0.034602    1.098039       1.000000  0.142857   0.089286    0.571429
# 2   0.010381    1.029412       0.300000  0.125000   0.028571    0.321429
# 26  0.010381    1.029412       0.300000  0.125000   0.028571    0.321429
# 25  0.013841    1.019608       1.000000  0.076923   0.019231    0.538462
# 35  0.013841    1.019608       1.000000  0.076923   0.019231    0.538462
# 37  0.010381    1.013575       1.000000  0.071429   0.013393    0.535714
#
#          merged_items
# 9          角色表现|剧情合理性
# 8          剧情合理性|角色表现
# 5          叙事节奏|剧情合理性
# 4          剧情合理性|叙事节奏
# 7          文化深度|剧情合理性
# 6          剧情合理性|文化深度
# 15          台词质量|角色表现
# 38  剧情合理性|服化道匹配度|角色表现
# 30    文化深度|叙事节奏|剧情合理性
# 40  服化道匹配度|角色表现|剧情合理性
# 32    文化深度|剧情合理性|叙事节奏
# 12          文化深度|叙事节奏
# 28    剧情合理性|文化深度|叙事节奏
# 42  服化道匹配度|剧情合理性|角色表现
# 29    剧情合理性|叙事节奏|文化深度
# 13          叙事节奏|文化深度
# 33    叙事节奏|剧情合理性|文化深度
# 39  剧情合理性|角色表现|服化道匹配度
# 14          角色表现|台词质量
# 43  角色表现|剧情合理性|服化道匹配度
# 31    剧情合理性|文化深度|叙事节奏
# 41  剧情合理性|服化道匹配度|角色表现
# 18  服化道匹配度|nan|动作场面呈现
# 19  动作场面呈现|服化道匹配度|nan
# 10      动作场面呈现|服化道匹配度
# 16  动作场面呈现|nan|服化道匹配度
# 0          动作场面呈现|nan
# 17  动作场面呈现|服化道匹配度|nan
# 24      nan|台词质量|角色表现
# 34    剧情合理性|台词质量|角色表现
# 36    文化深度|角色表现|剧情合理性
# 27      台词质量|nan|角色表现
# 3            台词质量|nan
# 23      角色表现|台词质量|nan
# 11      服化道匹配度|动作场面呈现
# 21  服化道匹配度|动作场面呈现|nan
# 22      nan|角色表现|台词质量
# 1          nan|动作场面呈现
# 20  nan|动作场面呈现|服化道匹配度
# 2            nan|台词质量
# 26      nan|角色表现|台词质量
# 25      角色表现|nan|台词质量
# 35    角色表现|剧情合理性|台词质量
# 37    剧情合理性|文化深度|角色表现
# 第91集关联规则：
#        antecedents     consequents  antecedent support  consequent support  \
# 7           (叙事节奏)         (剧情合理性)            0.422297            0.827703
# 6          (剧情合理性)          (叙事节奏)            0.827703            0.422297
# 9           (文化深度)         (剧情合理性)            0.347973            0.827703
# 8          (剧情合理性)          (文化深度)            0.827703            0.347973
# 28    (角色表现, 叙事节奏)         (剧情合理性)            0.381757            0.827703
# 29         (剧情合理性)    (角色表现, 叙事节奏)            0.827703            0.381757
# 31    (文化深度, 角色表现)         (剧情合理性)            0.314189            0.827703
# 33          (文化深度)   (剧情合理性, 角色表现)            0.347973            0.766892
# 30   (剧情合理性, 角色表现)          (文化深度)            0.766892            0.347973
# 32         (剧情合理性)    (文化深度, 角色表现)            0.827703            0.314189
# 20   (服化道匹配度, nan)          (角色表现)            0.033784            0.929054
# 21  (服化道匹配度, 角色表现)           (nan)            0.097973            0.189189
# 23        (服化道匹配度)     (角色表现, nan)            0.111486            0.165541
# 4         (服化道匹配度)           (nan)            0.111486            0.189189
# 22     (角色表现, nan)        (服化道匹配度)            0.165541            0.111486
# 24           (nan)  (服化道匹配度, 角色表现)            0.189189            0.097973
# 5            (nan)        (服化道匹配度)            0.189189            0.111486
# 25          (角色表现)   (服化道匹配度, nan)            0.929054            0.033784
# 14         (音效与配乐)        (服化道匹配度)            0.043919            0.111486
# 15        (服化道匹配度)         (音效与配乐)            0.111486            0.043919
# 26    (文化深度, 叙事节奏)         (剧情合理性)            0.023649            0.827703
# 27         (剧情合理性)    (文化深度, 叙事节奏)            0.827703            0.023649
# 36   (音效与配乐, 角色表现)        (服化道匹配度)            0.030405            0.111486
# 38         (音效与配乐)  (服化道匹配度, 角色表现)            0.043919            0.097973
# 3           (台词质量)           (nan)            0.081081            0.189189
# 37  (服化道匹配度, 角色表现)         (音效与配乐)            0.097973            0.043919
# 39        (服化道匹配度)   (音效与配乐, 角色表现)            0.111486            0.030405
# 2            (nan)          (台词质量)            0.189189            0.081081
# 17    (角色表现, 台词质量)           (nan)            0.074324            0.189189
# 19          (台词质量)     (nan, 角色表现)            0.081081            0.165541
# 16     (nan, 角色表现)          (台词质量)            0.165541            0.081081
# 18           (nan)    (角色表现, 台词质量)            0.189189            0.074324
# 34  (动作场面呈现, 角色表现)          (叙事节奏)            0.027027            0.422297
# 35          (叙事节奏)  (动作场面呈现, 角色表现)            0.422297            0.027027
# 12         (音效与配乐)        (动作场面呈现)            0.043919            0.047297
# 13        (动作场面呈现)         (音效与配乐)            0.047297            0.043919
# 10        (动作场面呈现)        (服化道匹配度)            0.047297            0.111486
# 0         (动作场面呈现)           (nan)            0.047297            0.189189
# 11        (服化道匹配度)        (动作场面呈现)            0.111486            0.047297
# 1            (nan)        (动作场面呈现)            0.189189            0.047297
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 7   0.351351    0.832000  1.005192               1.0  0.001815    1.025579
# 6   0.351351    0.424490  1.005192               1.0  0.001815    1.003810
# 9   0.331081    0.951456  1.149515               1.0  0.043063    3.549324
# 8   0.331081    0.400000  1.149515               1.0  0.043063    1.086712
# 28  0.317568    0.831858  1.005021               1.0  0.001586    1.024716
# 29  0.317568    0.383673  1.005021               1.0  0.001586    1.003110
# 31  0.297297    0.946237  1.143208               1.0  0.037242    3.204730
# 33  0.297297    0.854369  1.114067               1.0  0.030440    1.600676
# 30  0.297297    0.387665  1.114067               1.0  0.030440    1.064821
# 32  0.297297    0.359184  1.143208               1.0  0.037242    1.070214
# 20  0.033784    1.000000  1.076364               1.0  0.002397         inf
# 21  0.033784    0.344828  1.822660               1.0  0.015248    1.237553
# 23  0.033784    0.303030  1.830550               1.0  0.015328    1.197268
# 4   0.033784    0.303030  1.601732               1.0  0.012692    1.163337
# 22  0.033784    0.204082  1.830550               1.0  0.015328    1.116337
# 24  0.033784    0.178571  1.822660               1.0  0.015248    1.098120
# 5   0.033784    0.178571  1.601732               1.0  0.012692    1.081669
# 25  0.033784    0.036364  1.076364               1.0  0.002397    1.002677
# 14  0.027027    0.615385  5.519814               1.0  0.022131    2.310135
# 15  0.027027    0.242424  5.519814               1.0  0.022131    1.262027
# 26  0.023649    1.000000  1.208163               1.0  0.004075         inf
# 27  0.023649    0.028571  1.208163               1.0  0.004075    1.005068
# 36  0.020270    0.666667  5.979798               1.0  0.016880    2.665541
# 38  0.020270    0.461538  4.710875               1.0  0.015967    1.675193
# 3   0.020270    0.250000  1.321429               1.0  0.004931    1.081081
# 37  0.020270    0.206897  4.710875               1.0  0.015967    1.205494
# 39  0.020270    0.181818  5.979798               1.0  0.016880    1.185060
# 2   0.020270    0.107143  1.321429               1.0  0.004931    1.029189
# 17  0.016892    0.227273  1.201299               1.0  0.002831    1.049285
# 19  0.016892    0.208333  1.258503               1.0  0.003470    1.054054
# 16  0.016892    0.102041  1.258503               1.0  0.003470    1.023342
# 18  0.016892    0.089286  1.201299               1.0  0.002831    1.016428
# 34  0.013514    0.500000  1.184000               1.0  0.002100    1.155405
# 35  0.013514    0.032000  1.184000               1.0  0.002100    1.005137
# 12  0.010135    0.230769  4.879121               1.0  0.008058    1.238514
# 13  0.010135    0.214286  4.879121               1.0  0.008058    1.216830
# 10  0.010135    0.214286  1.922078               1.0  0.004862    1.130835
# 0   0.010135    0.214286  1.132653               1.0  0.001187    1.031941
# 11  0.010135    0.090909  1.922078               1.0  0.004862    1.047973
# 1   0.010135    0.053571  1.132653               1.0  0.001187    1.006629
#
#     zhangs_metric   jaccard  certainty  kulczynski       merged_items
# 7        0.008941  0.390977   0.024941    0.628245         叙事节奏|剧情合理性
# 6        0.029977  0.390977   0.003795    0.628245         剧情合理性|叙事节奏
# 9        0.199482  0.392000   0.718256    0.675728         文化深度|剧情合理性
# 8        0.754902  0.392000   0.079793    0.675728         剧情合理性|文化深度
# 28       0.008080  0.356061   0.024119    0.607766    角色表现|叙事节奏|剧情合理性
# 29       0.028995  0.356061   0.003100    0.607766    剧情合理性|角色表现|叙事节奏
# 31       0.182658  0.352000   0.687961    0.652710    文化深度|角色表现|剧情合理性
# 33       0.157030  0.363636   0.375264    0.621017    文化深度|剧情合理性|角色表现
# 30       0.439229  0.363636   0.060875    0.621017    剧情合理性|角色表现|文化深度
# 32       0.727050  0.352000   0.065608    0.652710    剧情合理性|文化深度|角色表现
# 20       0.073427  0.036364   1.000000    0.518182    服化道匹配度|nan|角色表现
# 21       0.500375  0.133333   0.191954    0.261700    服化道匹配度|角色表现|nan
# 23       0.510646  0.138889   0.164765    0.253556    服化道匹配度|角色表现|nan
# 4        0.422814  0.126582   0.140404    0.240801         服化道匹配度|nan
# 22       0.543725  0.138889   0.104214    0.253556    角色表现|nan|服化道匹配度
# 24       0.556667  0.133333   0.089353    0.261700    nan|服化道匹配度|角色表现
# 5        0.463333  0.126582   0.075502    0.240801         nan|服化道匹配度
# 25       1.000000  0.036364   0.002670    0.518182    角色表现|服化道匹配度|nan
# 14       0.856449  0.210526   0.567125    0.428904       音效与配乐|服化道匹配度
# 15       0.921578  0.210526   0.207624    0.428904       服化道匹配度|音效与配乐
# 26       0.176471  0.028571   1.000000    0.514286    文化深度|叙事节奏|剧情合理性
# 27       1.000000  0.028571   0.005042    0.514286    剧情合理性|文化深度|叙事节奏
# 36       0.858885  0.166667   0.624842    0.424242  音效与配乐|角色表现|服化道匹配度
# 38       0.823910  0.166667   0.403054    0.334218  音效与配乐|服化道匹配度|角色表现
# 3        0.264706  0.081081   0.075000    0.178571           台词质量|nan
# 37       0.873283  0.166667   0.170464    0.334218  服化道匹配度|角色表现|音效与配乐
# 39       0.937262  0.166667   0.156161    0.424242  服化道匹配度|音效与配乐|角色表现
# 2        0.300000  0.081081   0.028361    0.178571           nan|台词质量
# 17       0.181022  0.068493   0.046970    0.158279      角色表现|台词质量|nan
# 19       0.223529  0.073529   0.051282    0.155187      台词质量|nan|角色表现
# 16       0.246154  0.073529   0.022809    0.155187      nan|角色表现|台词质量
# 18       0.206667  0.068493   0.016163    0.158279      nan|角色表现|台词质量
# 34       0.159722  0.031008   0.134503    0.266000   动作场面呈现|角色表现|叙事节奏
# 35       0.269006  0.031008   0.005111    0.266000   叙事节奏|动作场面呈现|角色表现
# 12       0.831567  0.125000   0.192580    0.222527       音效与配乐|动作场面呈现
# 13       0.834515  0.125000   0.178193    0.222527       动作场面呈现|音效与配乐
# 10       0.503546  0.068182   0.115698    0.152597      动作场面呈现|服化道匹配度
# 0        0.122931  0.044776   0.030952    0.133929         动作场面呈现|nan
# 11       0.539924  0.068182   0.045777    0.152597      服化道匹配度|动作场面呈现
# 1        0.144444  0.044776   0.006586    0.133929         nan|动作场面呈现
# C:\Users\lenovo\AppData\Roaming\Python\Python311\site-packages\mlxtend\frequent_patterns\association_rules.py:186: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)
# C:\Users\lenovo\AppData\Roaming\Python\Python311\site-packages\mlxtend\frequent_patterns\association_rules.py:186: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)

# %% [markdown]
# 在关联规则中，支持度（Support）指的是包含某个项集（或者规则）的事务数与总事务数之间的比率。它衡量了一个项集在所有事务中出现的频率。支持度高表示该项集经常出现，支持度低则表示该项集出现的频率较低。

# %% [markdown]
# ###考虑支持度

# %%
import pandas as pd
import os

# 设置工作目录
os.chdir('D:/研究生论文/小论文2/代码/03网络图/00关联分析_强关联规则/输出结果')

# 循环遍历处理第1集到第10集的文件
for episode in range(1, 92):
    # 读取数据
    data = pd.read_excel(f"./01关联规则结果/桃花马上请长缨RAG/第{episode}集.xlsx")

    # 将 support 列的值乘以 100 并取整，保存在 weight 列
    data['weight'] = (data['support'] * 100).astype(int)

    # 创建一个新的 DataFrame，每行重复 weight 列中的值次数
    repeated_data = data.loc[data.index.repeat(data['weight'])].reset_index(drop=True)

    # 保存结果
    repeated_data.to_excel(f"./02加入权重的关联规则/桃花马上请长缨RAG/第{episode}集_考虑support.xlsx", index=False)

    # 打印结果
    print(f"第{episode}集处理完成")

print("所有集处理完成")
# Out:
# 第1集处理完成
# 第2集处理完成
# 第3集处理完成
# 第4集处理完成
# 第5集处理完成
# 第6集处理完成
# 第7集处理完成
# 第8集处理完成
# 第9集处理完成
# 第10集处理完成
# 第11集处理完成
# 第12集处理完成
# 第13集处理完成
# 第14集处理完成
# 第15集处理完成
# 第16集处理完成
# 第17集处理完成
# 第18集处理完成
# 第19集处理完成
# 第20集处理完成
# 第21集处理完成
# 第22集处理完成
# 第23集处理完成
# 第24集处理完成
# 第25集处理完成
# 第26集处理完成
# 第27集处理完成
# 第28集处理完成
# 第29集处理完成
# 第30集处理完成
# 第31集处理完成
# 第32集处理完成
# 第33集处理完成
# 第34集处理完成
# 第35集处理完成
# 第36集处理完成
# 第37集处理完成
# 第38集处理完成
# 第39集处理完成
# 第40集处理完成
# 第41集处理完成
# 第42集处理完成
# 第43集处理完成
# 第44集处理完成
# 第45集处理完成
# 第46集处理完成
# 第47集处理完成
# 第48集处理完成
# 第49集处理完成
# 第50集处理完成
# 第51集处理完成
# 第52集处理完成
# 第53集处理完成
# 第54集处理完成
# 第55集处理完成
# 第56集处理完成
# 第57集处理完成
# 第58集处理完成
# 第59集处理完成
# 第60集处理完成
# 第61集处理完成
# 第62集处理完成
# 第63集处理完成
# 第64集处理完成
# 第65集处理完成
# 第66集处理完成
# 第67集处理完成
# 第68集处理完成
# 第69集处理完成
# 第70集处理完成
# 第71集处理完成
# 第72集处理完成
# 第73集处理完成
# 第74集处理完成
# 第75集处理完成
# 第76集处理完成
# 第77集处理完成
# 第78集处理完成
# 第79集处理完成
# 第80集处理完成
# 第81集处理完成
# 第82集处理完成
# 第83集处理完成
# 第84集处理完成
# 第85集处理完成
# 第86集处理完成
# 第87集处理完成
# 第88集处理完成
# 第89集处理完成
# 第90集处理完成
# 第91集处理完成
# 所有集处理完成

# %% [markdown]
# ##将关联规则转换为共线关系所需数据

# %%
import os
import pandas as pd

# 设置工作目录
os.chdir("D:/研究生论文/小论文2/代码/03网络图/00关联分析_强关联规则/输出结果/02加入权重的关联规则/桃花马上请长缨RAG")

# 循环处理第1集到第10集的文件
for episode in range(1, 92):
    # 读取数据
    file_path = f"第{episode}集_考虑support.xlsx"
    data = pd.read_excel(file_path)

    # 创建新列，根据 '|' 符号拆分 merged_items 列，并命名新列
    split_columns = data['merged_items'].str.split('|', expand=True)
    split_columns.columns = [f"SFeature_{i+1}" for i in range(split_columns.shape[1])]

    # 将拆分后的列添加到原始数据框中
    data = pd.concat([data, split_columns], axis=1)

    # 保存结果
    output_file_path = f"D:/研究生论文/小论文2/代码/03网络图/00关联分析_强关联规则/输出结果/03共线关系预备数据/桃花马上请长缨RAG/第{episode}集_拆分.xlsx"
    data.to_excel(output_file_path, index=False)

    # 打印处理完毕信息
    print(f"处理第{episode}集完成。")

print("所有集处理完成。")
# Out:
# 处理第1集完成。
# 处理第2集完成。
# 处理第3集完成。
# 处理第4集完成。
# 处理第5集完成。
# 处理第6集完成。
# 处理第7集完成。
# 处理第8集完成。
# 处理第9集完成。
# 处理第10集完成。
# 处理第11集完成。
# 处理第12集完成。
# 处理第13集完成。
# 处理第14集完成。
# 处理第15集完成。
# 处理第16集完成。
# 处理第17集完成。
# 处理第18集完成。
# 处理第19集完成。
# 处理第20集完成。
# 处理第21集完成。
# 处理第22集完成。
# 处理第23集完成。
# 处理第24集完成。
# 处理第25集完成。
# 处理第26集完成。
# 处理第27集完成。
# 处理第28集完成。
# 处理第29集完成。
# 处理第30集完成。
# 处理第31集完成。
# 处理第32集完成。
# 处理第33集完成。
# 处理第34集完成。
# 处理第35集完成。
# 处理第36集完成。
# 处理第37集完成。
# 处理第38集完成。
# 处理第39集完成。
# 处理第40集完成。
# 处理第41集完成。
# 处理第42集完成。
# 处理第43集完成。
# 处理第44集完成。
# 处理第45集完成。
# 处理第46集完成。
# 处理第47集完成。
# 处理第48集完成。
# 处理第49集完成。
# 处理第50集完成。
# 处理第51集完成。
# 处理第52集完成。
# 处理第53集完成。
# 处理第54集完成。
# 处理第55集完成。
# 处理第56集完成。
# 处理第57集完成。
# 处理第58集完成。
# 处理第59集完成。
# 处理第60集完成。
# 处理第61集完成。
# 处理第62集完成。
# 处理第63集完成。
# 处理第64集完成。
# 处理第65集完成。
# 处理第66集完成。
# 处理第67集完成。
# 处理第68集完成。
# 处理第69集完成。
# 处理第70集完成。
# 处理第71集完成。
# 处理第72集完成。
# 处理第73集完成。
# 处理第74集完成。
# 处理第75集完成。
# 处理第76集完成。
# 处理第77集完成。
# 处理第78集完成。
# 处理第79集完成。
# 处理第80集完成。
# 处理第81集完成。
# 处理第82集完成。
# 处理第83集完成。
# 处理第84集完成。
# 处理第85集完成。
# 处理第86集完成。
# 处理第87集完成。
# 处理第88集完成。
# 处理第89集完成。
# 处理第90集完成。
# 处理第91集完成。
# 所有集处理完成。

# %% [markdown]
# #单集-关联规则获取

# %%
import os
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules


# 读取数据
data = pd.read_excel("D:/研究生论文/小论文2/代码/02质量特征识别/百妖谱_每集/mapped_info_episode_1.xlsx")


# 合并三列为一列，并使用'|'连接
merged_features = data[['Feature_1', 'Feature_2', 'Feature_3']].astype(str).apply(lambda x: '|'.join(x), axis=1)

# 将合并后的列添加到原始数据框中
data['Merged_Features'] = merged_features

# 对合并后的数据进行处理，转换成适合关联分析的格式
transaction_list = data['Merged_Features'].apply(lambda x: x.split('|')).tolist()

# 使用 TransactionEncoder 进行编码
te = TransactionEncoder()
te_ary = te.fit(transaction_list).transform(transaction_list)
df = pd.DataFrame(te_ary, columns=te.columns_)

# 使用 Apriori 算法找出频繁项集
frequent_itemsets = apriori(df, min_support=0.05, use_colnames=True)

# 根据频繁项集生成关联规则
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# 排序
rules = rules.sort_values(by=['support', 'confidence', 'lift'], ascending=[False, False, False])

# 提取关联规则中的项并合并到一列
rules['merged_items'] = rules.apply(lambda row: '|'.join(row['antecedents']) + '|' + '|'.join(row['consequents']), axis=1)


# 保存结果
rules.to_excel("D:/研究生论文/小论文2/代码/03网络图/00关联分析_强关联规则/输出结果/百妖谱/关联规则结果/第1集.xlsx", index=False)

# 打印关联规则
print(rules)
# Out:
#           antecedents        consequents  antecedent support  \
# 3                (人物)               (剧情)            0.517312
# 2                (剧情)               (人物)            0.678208
# 1                (主题)               (剧情)            0.311609
# 0                (剧情)               (主题)            0.678208
# 8     (整体适应性与创新性, 人物)               (剧情)            0.230143
# 9                (剧情)    (整体适应性与创新性, 人物)            0.678208
# 5              (声音设计)             (画面质量)            0.299389
# 4              (画面质量)             (声音设计)            0.327902
# 6            (主题, 人物)               (剧情)            0.130346
# 7                (剧情)           (主题, 人物)            0.678208
# 11  (整体适应性与创新性, 声音设计)             (画面质量)            0.150713
# 10  (画面质量, 整体适应性与创新性)             (声音设计)            0.164969
# 13             (声音设计)  (画面质量, 整体适应性与创新性)            0.299389
# 12             (画面质量)  (整体适应性与创新性, 声音设计)            0.327902
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 3             0.678208  0.397149    0.767717  1.131978  0.046304    1.385343
# 2             0.517312  0.397149    0.585586  1.131978  0.046304    1.164748
# 1             0.678208  0.232179    0.745098  1.098628  0.020844    1.262416
# 0             0.311609  0.232179    0.342342  1.098628  0.020844    1.046732
# 8             0.678208  0.171079    0.743363  1.096070  0.014995    1.253880
# 9             0.230143  0.171079    0.252252  1.096070  0.014995    1.029568
# 5             0.327902  0.156823    0.523810  1.597456  0.058652    1.411405
# 4             0.299389  0.156823    0.478261  1.597456  0.058652    1.342838
# 6             0.678208  0.105906    0.812500  1.198011  0.017504    1.716225
# 7             0.130346  0.105906    0.156156  1.198011  0.017504    1.030586
# 11            0.327902  0.075356    0.500000  1.524845  0.025937    1.344196
# 10            0.299389  0.075356    0.456790  1.525741  0.025966    1.289761
# 13            0.164969  0.075356    0.251701  1.525741  0.025966    1.115904
# 12            0.150713  0.075356    0.229814  1.524845  0.025937    1.102704
#
#            merged_items
# 3                 人物|剧情
# 2                 剧情|人物
# 1                 主题|剧情
# 0                 剧情|主题
# 8       整体适应性与创新性|人物|剧情
# 9       剧情|整体适应性与创新性|人物
# 5             声音设计|画面质量
# 4             画面质量|声音设计
# 6              主题|人物|剧情
# 7              剧情|主题|人物
# 11  整体适应性与创新性|声音设计|画面质量
# 10  画面质量|整体适应性与创新性|声音设计
# 13  声音设计|画面质量|整体适应性与创新性
# 12  画面质量|整体适应性与创新性|声音设计

# %% [markdown]
# ###考虑support

# %%
import pandas as pd
import os
os.chdir('D:/研究生论文/小论文2/代码/03网络图/00关联分析_强关联规则/输出结果')
# 读取数据
data = pd.read_excel("./01关联规则结果/百妖谱/第1集.xlsx")

# 将 support 列的值乘以 100 并取整，保存在 weight 列
data['weight'] = (data['support'] * 100).astype(int)

# 创建一个新的 DataFrame，每行重复 weight 列中的值次数
repeated_data = data.loc[data.index.repeat(data['weight'])].reset_index(drop=True)

# 保存结果
repeated_data.to_excel("./02加入权重的关联规则/百妖谱/第1集_考虑support.xlsx", index=False)

# 打印结果
print(repeated_data)

# %%
import os
import pandas as pd

# 读取数据
data = pd.read_excel("D:/研究生论文/小论文2/代码/03网络图/00关联分析_强关联规则/输出结果/0202加入权重的关联规则/百妖谱/第1集_考虑support.xlsx")

# 创建新列，根据 '|' 符号拆分 merged_items 列，并命名新列
split_columns = data['merged_items'].str.split('|', expand=True)
split_columns.columns = [f"SFeature_{i+1}" for i in range(split_columns.shape[1])]

# 将拆分后的列添加到原始数据框中
data = pd.concat([data, split_columns], axis=1)

# 保存结果
data.to_excel("D:/研究生论文/小论文2/代码/03网络图/00关联分析_强关联规则/输出结果/03共线关系预备数据/百妖谱/第1集_拆分.xlsx", index=False)

# 打印结果
print(data)
